# %%
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.core.display import display, HTML

def webscraping_example(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    data = soup.find_all('p')
    return [paragraph.text for paragraph in data]


url = 'https://example.com'
scraped_data = webscraping_example(url)
print(scraped_data)

plt.figure(figsize=(10, 6))
plt.bar(range(len(scraped_data)), [len(p) for p in scraped_data])
plt.xticks(range(len(scraped_data)), [f'Párrafo {i+1}' for i in range(len(scraped_data))])
plt.title('Longitud de los párrafos extraídos')
plt.xlabel('Párrafos')
plt.ylabel('Número de caracteres')
plt.show()

data = [1, 2, 2, 3, 4, 5]

mean = np.mean(data)
median = np.median(data)
mode = pd.Series(data).mode()[0]

print(f"Media: {mean}, Mediana: {median}, Moda: {mode}")

variance = np.var(data)
std_dev = np.std(data)

print(f"Varianza: {variance}, Desviación estándar: {std_dev}")

plt.figure(figsize=(10, 6))
plt.hist(data, bins=5, alpha=0.7, color='blue')
plt.axvline(mean, color='red', linestyle='dashed', linewidth=1, label='Media')
plt.axvline(median, color='green', linestyle='dashed', linewidth=1, label='Mediana')
plt.legend()
plt.title('Distribución de los datos')
plt.xlabel('Valores')
plt.ylabel('Frecuencia')
plt.show()

# CODIGO HTML
html_code = """
<!DOCTYPE html>
<html lang="es">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>CIENCIA DE DATOS</title>
    <style>
        body {
            background-color: #d0e8f2; /* Color de fondo */
            font-family: Arial, sans-serif;
            color: #333333; /* Color de texto */
        }
        header {
            text-align: center;
            padding: 1.5rem;
            background-color: #1e3d59; /* Color de encabezado */
            color: white;
        }
        section {
            margin: 20px;
            padding: 20px;
            border: 1px solid #ccc;
            border-radius: 10px;
            background-color: #ffffff; /* Fondo blanco para secciones */
        }
        h1 {
            color: #ffffff; /* Color blanco del título */
            font-size: 3rem; /* Tamaño grande del título */
            font-weight: bold;
            margin-bottom: 0;
        }
        h2, h3 {
            color: #1e3d59; /* Color oscuro para subtítulos */
            text-align: center; /* Centrar títulos secundarios */
            margin: 20px 0; /* Espacio superior e inferior para los títulos */
        }
        a {
            color: #0077b6; /* Color azul para los enlaces */
            text-decoration: none;
        }
        a:hover {
            color: #005f8c; /* Enlaces cuando se pasa el cursor */
        }
        pre {
            background-color: #f4f4f4; /* Fondo gris claro para el código */
            padding: 10px;
            border-radius: 5px;
            overflow-x: auto;
        }
    </style>
</head>
<body>

<header>
    <h1>CIENCIA DE DATOS</h1>
</header>

<section id="WEBSCRAPING">
    <h2>WEBSCRAPING</h2>
    <p>El WEBSCRAPING es una técnica utilizada para extraer datos de sitios web. Utiliza programas para simular la navegación y recopilar información.</p>
    <p><strong>Contexto:</strong> En un mundo donde la información está disponible en línea, la capacidad de extraer datos de páginas web es fundamental para obtener insights valiosos. Por ejemplo, una empresa podría necesitar datos de precios de productos para realizar un análisis competitivo.</p>
    <img src="ruta/a/tu/imagen_webscraping.jpg" alt="Webscraping" style="width:100%; height:auto;">
    <p>En el <a href="https://medium.com/geekculture/web-scraping-with-python-a-complete-step-by-step-guide-code-5174e52340ea">LINK Directo</a>
    Informacion sobre webscraping.</p>
    <pre>
   <p>VIDEO <a href="https://youtu.be/WXK0u2yXLrU?si=AQNwymOhtPa49bDj">LINK DIRECTO</a>

import requests
from bs4 import BeautifulSoup

url = 'https://example.com'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
data = soup.find_all('p')
for paragraph in data:
    print(paragraph.text)
    </pre>
</section>

<section id="Visualizacion">
    <h2>Técnicas de Visualización</h2>
    <p>Las técnicas de visualización de datos ayudan a representar información de manera gráfica, facilitando su análisis e interpretación.</p>
    <p><strong>Contexto:</strong> Al analizar grandes volúmenes de datos, puede ser difícil identificar patrones. Las visualizaciones permiten a los analistas y tomadores de decisiones comprender mejor la información de un vistazo.</p>
    <img src="ruta/a/tu/imagen_visualizacion.jpg" alt="Visualización" style="width:100%; height:auto;">
    <p>En el <a href="https://www.tableau.com/es-es/learn/articles/data-visualization">Click para mas info</a>
    Ejemplo de visualización.</p>
    <pre>
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Ejemplo de datos
data = pd.DataFrame({
    'categoría': ['A', 'B', 'C'],
    'valores': [10, 20, 15]
})

sns.barplot(x='categoría', y='valores', data=data)
plt.title('Ejemplo de Visualización')
plt.show()
    </pre>
</section>

<section id="TENDENCIA-CENTRAL">
    <h2>MEDIDAS DE TENDENCIA CENTRAL</h2>
    <p>Las medidas de tendencia central, como la media, mediana y moda, son estadísticas que describen el centro de un conjunto de datos.</p>
    <p><strong>Contexto:</strong> Comprender el centro de un conjunto de datos es crucial para el análisis. Por ejemplo, en estudios de población, estas medidas ayudan a resumir la información demográfica y facilitar comparaciones.</p>
    <img src="ruta/a/tu/imagen_tendencia_central.jpg" alt="Tendencia Central" style="width:100%; height:auto;">
    <p>En el <a href="https://www.probabilidadyestadistica.net/medidas-de-tendencia-central/">Clic para mas Info</a>
    Ejemplo de medidas de tendencia central.</p>
    <pre>
      <p>VIDEO <a href="https://youtu.be/KFB5mWICDeQ?si=bBXW_JBYjslbkO9B">LINK DIRECTO</a>
import numpy as np
import pandas as pd

data = [1, 2, 2, 3, 4, 5]
mean = np.mean(data)
median = np.median(data)
mode = pd.Series(data).mode()[0]

print(f"Media: {mean}, Mediana: {median}, Moda: {mode}")
    </pre>
</section>

<section id="Disersion">
    <h2>Medidas de Dispersión</h2>
    <p>Las medidas de dispersión, como la varianza y la desviación estándar, indican cuán dispersos están los datos respecto a la media.</p>
    <p><strong>Contexto:</strong> Entender la variabilidad de los datos es esencial en campos como la estadística y la investigación.
    Por ejemplo, en un estudio de calidad, saber cuán dispersos están los resultados puede influir en la interpretación de la eficacia de un producto.</p>
    <img src="ruta/a/tu/imagen_dispersión.jpg" alt="Dispersión" style="width:100%; height:auto;">
    <p>En el <a href="https://www.lifeder.com/medidas-de-dispersion/">HIPERVINCULO</a>
    Mas Informacion acerca del tema.</p>
    <pre>
import numpy as np

data = [1, 2, 2, 3, 4, 5]
variance = np.var(data)
std_dev = np.std(data)

print(f"Varianza: {variance}, Desviación estándar: {std_dev}")
    </pre>
</section>

</body>
</html>
"""


with open('proyecto_ciencia_datos.html', 'w') as file:
    file.write(html_code)


display(HTML('proyecto_ciencia_datos.html'))
# Out:
# ['This domain is for use in illustrative examples in documents. You may use this\n    domain in literature without prior coordination or asking for permission.', 'More information...']
# Media: 2.8333333333333335, Mediana: 2.5, Moda: 2
# Varianza: 1.8055555555555554, Desviación estándar: 1.3437096247164249
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>CIENCIA DE DATOS</title>
#     <style>
#         body {
#             background-color: #d0e8f2; /* Color de fondo */
#             font-family: Arial, sans-serif;
#             color: #333333; /* Color de texto */
#         }
#         header {
#             text-align: center;
#             padding: 1.5rem;
#             background-color: #1e3d59; /* Color de encabezado */
#             color: white;
#         }
#         section {
#             margin: 20px;
#             padding: 20px;
# ...
